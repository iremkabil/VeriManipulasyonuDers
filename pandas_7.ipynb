# %% [markdown]
# # Pivot Tablolar

# %%
import pandas as pd
import seaborn as sns
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df = pd.DataFrame(titanic)
print("min: " + str(df['age'].min())+"\nmax: " +str(df['age'].max()))
# Out:
# min: 0.42
# max: 80.0

# %%
df['age_group']= pd.cut(df['age'], bins=range(0,81,10))
survival_rates = (df.groupby('age_group')[['survived']].mean())*100
survival_rates = survival_rates.astype(str) + "%"
survival_rates
# Out:
#                       survived
# age_group
# (0, 10]                59.375%
# (10, 20]    38.26086956521739%
# (20, 30]    36.52173913043478%
# (30, 40]   44.516129032258064%
# (40, 50]   38.372093023255815%
# (50, 60]   40.476190476190474%
# (60, 70]    23.52941176470588%
# (70, 80]                 20.0%

# %%
titanic.groupby("sex")[["survived"]].mean()
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908

# %% [markdown]
# aşağıdaki iki tablo aynı

# %%
titanic.groupby("class")["survived"].mean()
# Out:
# class
# First     0.629630
# Second    0.472826
# Third     0.242363
# Name: survived, dtype: float64

# %%
titanic.groupby("class")[["survived"]].mean()
# Out:
#         survived
# class
# First   0.629630
# Second  0.472826
# Third   0.242363

# %%
titanic.groupby(["sex","class"])[["survived"]].aggregate("mean").unstack()
# Out:
#         survived
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
titanic.groupby(["sex","class"])[["survived"]].aggregate("mean")
# Out:
#                survived
# sex    class
# female First   0.968085
#        Second  0.921053
#        Third   0.500000
# male   First   0.368852
#        Second  0.157407
#        Third   0.135447

# %% [markdown]
# ## Pivot ile Table

# %%
titanic.pivot_table("survived",index="sex", columns = "class")
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
age = pd.cut(titanic["age"], [0,18,90])
age.head(10)
# Out:
# 0    (18.0, 90.0]
# 1    (18.0, 90.0]
# 2    (18.0, 90.0]
# 3    (18.0, 90.0]
# 4    (18.0, 90.0]
# 5             NaN
# 6    (18.0, 90.0]
# 7     (0.0, 18.0]
# 8    (18.0, 90.0]
# 9     (0.0, 18.0]
# Name: age, dtype: category
# Categories (2, interval[int64, right]): [(0, 18] < (18, 90]]

# %%
titanic.pivot_table("survived", ["sex",age], "class")
# Out:
# class               First    Second     Third
# sex    age
# female (0, 18]   0.909091  1.000000  0.511628
#        (18, 90]  0.972973  0.900000  0.423729
# male   (0, 18]   0.800000  0.600000  0.215686
#        (18, 90]  0.375000  0.071429  0.133663

# %%
seri = pd.Series([121,200,150,99])

seri.values
# Out:
# array([121, 200, 150,  99], dtype=int64)
